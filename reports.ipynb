# %%
from reports.reports import *

# %%
tempo_report = TempoReport()
jira_report = JiraReports()
merge_report = JiraTempoReport()
# Out:
# 1ere étape {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Authorization': 'Bearer O8Is_WcC9Njth_4zeb8gD0dro2GeI77Dele4VsrUmTo-us'}
# 1ere étape {'User-Agent': 'python-requests/2.31.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive', 'Authorization': 'Bearer O8Is_WcC9Njth_4zeb8gD0dro2GeI77Dele4VsrUmTo-us'}

# %%
start_date = '2024-04-22'
end_date = '2024-04-27'

# %%
test_merge_report = merge_report.get_merged_report(start_date, end_date, 'Benoit Leboucher', "csv/benoit-22-04-2024.csv")
test_merge_report
# Out:
# Le fichier CSV a été créé avec succès à l'emplacement : csv/benoit-22-04-2024.csv
#         Issue Key  Total Time Spent  Estimated Time  Period's Logged Time  \
# 0      VSP13526-1          2.000000            2.00                  0.25
# 1   SOUTIEN-11486          0.750000            1.00                  0.67
# 2   SOUTIEN-11485          0.500000            1.00                  0.50
# 3   SOUTIEN-11484          0.500000            0.50                  0.50
# 4   SOUTIEN-11481          0.500000            0.50                  0.25
# 5   SOUTIEN-11480          0.750000            1.00                  0.75
# 6   SOUTIEN-11479          1.000000            1.00                  1.00
# 7   SOUTIEN-11477          1.000000            0.75                  0.75
# 8   SOUTIEN-11475          0.833333            1.00                  0.75
# 9   SOUTIEN-11472          1.500000            1.00                  1.26
# 10  SOUTIEN-11471          0.916667            1.00                  0.84
# ...

# %%
sonia_report = merge_report.get_merged_report(start_date, end_date, 'Sonia Marquette', "csv/sonia-22-04-2024.csv")
sonia_report
# Out:
# Le fichier CSV a été créé avec succès à l'emplacement : csv/sonia-22-04-2024.csv
#         Issue Key  Total Time Spent  Estimated Time  Period's Logged Time  \
# 0   SOUTIEN-11488          1.000000            2.00                  0.50
# 1   SOUTIEN-11482          1.000000            1.00                  0.50
# 2   SOUTIEN-11478          1.333333            2.00                  0.83
# 3   SOUTIEN-11476          1.000000            1.00                  0.50
# 4   SOUTIEN-11474          1.250000            2.00                  1.00
# 5   SOUTIEN-11473          1.500000            2.00                  1.00
# 6   SOUTIEN-11470          1.750000            2.00                  1.25
# 7   SOUTIEN-11443          2.000000            2.00                  0.75
# 8   SOUTIEN-11442          1.250000            2.00                  0.75
# 9   SOUTIEN-11435          1.500000            2.00                  0.75
# 10  SOUTIEN-11434          2.000000            2.00                   NaN
# ...

# %%
claire_report = merge_report.get_merged_report(start_date, end_date, 'Claire Conrardy', "csv/claire-22-04-2024.csv")
claire_report
# Out:
# Le fichier CSV a été créé avec succès à l'emplacement : csv/claire-22-04-2024.csv
#         Issue Key  Total Time Spent  Estimated Time  Period's Logged Time  \
# 0     TEL12919-30          0.500000        0.500000                  0.50
# 1      TEL12919-9         16.416667       12.000000                  6.75
# 2   SOUTIEN-11468          2.750000        4.000000                  2.25
# 3   SOUTIEN-11408          6.000000        6.000000                  1.75
# 4      CSN13149-8          0.750000       10.000000                  0.25
# 5    CGU12657-135         10.500000        0.000000                  2.00
# 6     CDC12758-54          9.000000        2.666667                  8.75
# 7     CDC12758-53          9.000000        9.000000                  3.50
# 8     ACT11304-14         49.916667        0.000000                  3.00
# 9     AAO13097-24          3.500000        3.000000                  2.75
# 10  SOUTIEN-11437               NaN             NaN                  0.75
# ...

# %%
julien_report = merge_report.get_merged_report(start_date, end_date, 'Julien Le Mée', "csv/julien-22-04-2024.csv")
julien_report
# Out:
# Le fichier CSV a été créé avec succès à l'emplacement : csv/julien-22-04-2024.csv
#      Issue Key  Total Time Spent  Estimated Time  Period's Logged Time  \
# 0  MAT13045-62          5.916667            10.0                  5.67
# 1  BRW12531-96          2.500000            15.0                   NaN
# 2   ACT11304-9         84.166667             0.0                  1.33
# 3   ADM13161-4               NaN             NaN                  0.50
#
#    Period's Leaked Time  Total Leaked Time
# 0                  0.00               0.00
# 1                  0.00               0.00
# 2                  1.33              84.17
# 3                   NaN               0.00

# %%
idriss_report = merge_report.get_merged_report(start_date, end_date, 'Idriss Alami', "csv/idriss-15-04-2024.csv")
idriss_report
# Out:
# Le fichier CSV a été créé avec succès à l'emplacement : csv/idriss-15-04-2024.csv
#         Issue Key  Total Time Spent  Estimated Time  Period's Logged Time  \
# 0      SEH11553-4          5.000000            5.00                  0.25
# 1      SEH11553-1         61.416667           60.00                  2.58
# 2      SEH11533-1          6.500000           38.00                  0.75
# 3      SEH11095-1         25.666667           45.00                  3.00
# 4     RIC12948-38          2.250000            2.00                  0.25
# 5      MLS13144-1         35.416667           35.00                  1.83
# 6     MAT13045-15         75.500000           77.00                  4.50
# 7      JMJ13048-1         38.500000           35.90                  1.25
# 8      CSR12918-1         26.524167           42.75                  3.50
# 9      CMC13563-1          8.250000           15.00                  1.00
# 10    CIP12847-54          8.833333            8.00                  0.25
# ...

# %%
Laurence_report = merge_report.get_merged_report(start_date, end_date, 'Laurence Cauchon', "csv/Laurence-22-04-2024.csv")
Laurence_report
# Out:
# Le fichier CSV a été créé avec succès à l'emplacement : csv/Laurence-22-04-2024.csv
#         Issue Key  Total Time Spent  Estimated Time  Period's Logged Time  \
# 0      TEL12919-6         36.000000       36.000000                  0.50
# 1     SEH11553-17          2.000000        2.000000                  2.00
# 2     SEH11553-16          1.000000        1.000000                  1.00
# 3      SEH11095-5         20.000000       20.000000                  4.92
# 4      MJM13656-1          1.000000        1.000000                  1.00
# 5      CSR12918-1         29.524167       42.750000                  0.75
# 6     CDC12758-22          5.333333        5.333333                  2.17
# 7     CDC12758-21          9.000000        9.000000                  2.66
# 8      ACT11304-2         57.433333        0.000000                  2.58
# 9     AAO13097-26          9.250000       10.000000                  9.25
# ...

# %%
eric_report = merge_report.get_merged_report(start_date, end_date, 'Eric Ferole', "csv/eric-22-04-2024.csv")
eric_report
# Out:
# Le fichier CSV a été créé avec succès à l'emplacement : csv/eric-22-04-2024.csv
#        Issue Key  Total Time Spent  Estimated Time  Period's Logged Time  \
# 0  SOUTIEN-11360               2.0             2.0                   1.0
# 1    SEH11095-10               1.0             3.0                   1.0
# 2    AAO13097-13               NaN             NaN                   0.5
# 3     AAO13097-1               NaN             NaN                   1.0
# 4    AAO13097-22               NaN             NaN                   2.0
#
#    Period's Leaked Time  Total Leaked Time
# 0                   0.0                  0
# 1                   0.0                  0
# 2                   NaN                  0
# 3                   NaN                  0
# 4                   NaN                  0

# %%
plts = test_merge_report['Period\'s Leaked Time'].sum()
plts
# Out:
# 20.25

# %%
plogts = test_merge_report['Period\'s Logged Time'].sum()
plogts
# Out:
# 30.0

# %%
department_availability = jira_report.get_department_availlability()
# Out:
# 269.0
